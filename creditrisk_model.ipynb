# %% [markdown]
# # <h1><center>**`Model Building`**</center></h1>

# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
load_data_inputs_train=pd.read_csv('loan_data_inputs_train.csv',index_col=0)
load_data_targets_train=pd.read_csv('loan_data_targets_train.csv',index_col=0)
load_data_inputs_test=pd.read_csv('loan_data_inputs_test.csv',index_col=0)
load_data_targets_test=pd.read_csv('loan_data_targets_test.csv',index_col=0)

# %%
load_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:20-25 dti:25-30 dti:30-35 dti:35-40  dti:>40  \
# 427211         1         0         0         0        0
# 206088         0         0         0         0        0
# 136020         0         0         0         0        0
# 412305         0         0         0         0        0
# 36159          1         0         0         0        0
#
#        mths_since_last_record:Missing mths_since_last_record:0-90  \
# 427211                              1                           0
# 206088                              1                           0
# 136020                              1                           0
# 412305                              1                           0
# 36159                               1                           0
#
#        mths_since_last_record:90-120 mths_since_last_record:120-127  \
# 427211                             0                              0
# 206088                             0                              0
# 136020                             0                              0
# 412305                             0                              0
# 36159                              0                              0
#
#        mths_since_last_record:>=127
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 338 columns]

# %%
load_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
load_data_inputs_train.shape
# Out:
# (373028, 338)

# %%
load_data_targets_train.shape
# Out:
# (373028, 1)

# %%
load_data_inputs_test.shape
# Out:
# (373028, 338)

# %%
load_data_targets_test.shape
# Out:
# (93257, 1)

# %%
load_data_targets_test.head()
# Out:
#         good_bad
# 362514         1
# 288564         1
# 213591         1
# 263083         1
# 165001         1

# %%
feature_selection=[
'grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NC_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Verified',
'verification_status:Source Verified',
'verification_status:Not Verified',
    'purpose:educ_sm_b_wedd_ren_en_mov_house',
    'purpose:small_business',
    'purpose:educational',
    'purpose:renewable_energy',
    'purpose:moving',
    'purpose:house',
    'purpose:other',
    'purpose:medical',
    'purpose:wedding',
    'purpose:vacation',
    'purpose:debt_consolidation',
    'purpose:home_improvement',
    'purpose:major_purchase',
    'purpose:car',
    'purpose:credit_card',
    'initial_list_status:f',
    'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issued_date:<38',
'mths_since_issued_date:38-39',
'mths_since_issued_date:40-41',
'mths_since_issued_date:42-48',
'mths_since_issued_date:49-52',
'mths_since_issued_date:53-64',
'mths_since_issued_date:65-84',
'mths_since_issued_date:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:20.281',
    'mths_since_earliest_cr_line:<140',
    'mths_since_earliest_cr_line:140-239',
    'mths_since_earliest_cr_line:240-339',
    'mths_since_earliest_cr_line:340-439',
    'mths_since_earliest_cr_line:440-539',
    'mths_since_earliest_cr_line:540-600',
    'mths_since_earliest_cr_line:>600',
    'delinq_2yrs:0',
    'delinq_2yrs:0-3',
    'delinq_2yrs:3-7',
    'delinq_2yrs:7-9',
    'delinq_2yrs:9-11',
    'delinq_2yrs:11-12',
    'delinq_2yrs:12-18',
    'delinq_2yrs:>18',
    'inq_last_6mths:0',
    'inq_last_6mths:0-3',
    'inq_last_6mths:3-7',
    'inq_last_6mths:7-9',
    'inq_last_6mths:9-11',
    'inq_last_6mths:11-12',
    'inq_last_6mths:12-18',
    'inq_last_6mths:18',
    'open_acc:=0',
    'open_acc:0-1',
    'open_acc:1-4',
    'open_acc:4-28',
    'open_acc:28-35',
    'open_acc:35-45',
    'open_acc:>45',
    'pub_rec:0-3',
    'pub_rec:3-6',
    'pub_rec:6-8',
    'pub_rec:8',
    'total_acc:<0',
    'total_acc:0-4',
    'total_acc:4-62',
    'total_acc:62-72',
    'total_acc:72-85',
    'total_acc:>85',
    'acc_now_delinq:<0',
    'acc_now_delinq:0-1',
    'acc_now_delinq:1-2',
    'acc_now_delinq:2-3',
    'acc_now_delinq:3-5',
    'acc_now_delinq:>5',
'annual_inc:<20k',
'annual_inc:20k-30k',
'annual_inc:30k-40k',
'annual_inc:40k-50k',
'annual_inc:50k-60k',
'annual_inc:60k-70k',
'annual_inc:70k-80k',
'annual_inc:80k-90k',
'annual_inc:90k-100k',
'annual_inc:100k-120k',
'annual_inc:120k-140k',
'annual_inc:>140k',
'total_rev_hi_lim:<=5k',
'total_rev_hi_lim:5k_10k',
'total_rev_hi_lim:10k_20k',
'total_rev_hi_lim:20k_30k',
'total_rev_hi_lim:30k_40k',
'total_rev_hi_lim:40k_50k',
'total_rev_hi_lim:50k_65k',
'total_rev_hi_lim:65k_80k',
'total_rev_hi_lim:>80k',
'dti:<5',
'dti:5-10',
'dti:10-15',
'dti:15-20',
'dti:20-25',
'dti:25-30',
'dti:30-35',
'dti:35-40',
'dti:>40',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-90',
'mths_since_last_record:90-120',
'mths_since_last_record:120-127',
'mths_since_last_record:>=127','loan_amnt','funded_amnt','int_rate','installment']

# %%
inputs_train_with_ref_category = load_data_inputs_train.reindex(feature_selection, axis='columns')

# %%
inputs_train_with_ref_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373028 entries, 427211 to 121958
# Columns: 152 entries, grade:A to installment
# dtypes: float64(2), int64(150)
# memory usage: 435.4 MB

# %%
inputs_train_with_ref_category.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 427211        1        0        0        0        0        0        0
# 206088        0        0        1        0        0        0        0
# 136020        1        0        0        0        0        0        0
# 412305        0        0        0        1        0        0        0
# 36159         0        0        1        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 427211                                   0                   0
# 206088                                   0                   0
# 136020                                   0                   0
# 412305                                   1                   0
# 36159                                    0                   0
#
#         home_ownership:MORTGAGE  ...  mths_since_last_delinq:>=57  \
# 427211                        1  ...                            0
# 206088                        1  ...                            0
# 136020                        1  ...                            0
# 412305                        0  ...                            0
# 36159                         1  ...                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-90  \
# 427211                               1                            0
# 206088                               1                            0
# 136020                               1                            0
# 412305                               1                            0
# 36159                                1                            0
#
#         mths_since_last_record:90-120  mths_since_last_record:120-127  \
# 427211                              0                               0
# 206088                              0                               0
# 136020                              0                               0
# 412305                              0                               0
# 36159                               0                               0
#
#         mths_since_last_record:>=127  loan_amnt  funded_amnt  int_rate  \
# 427211                             0      24000        24000      8.90
# 206088                             0      10000        10000     14.33
# 136020                             0      20425        20425      8.90
# 412305                             0      17200        17200     16.59
# 36159                              0       8400         8400     12.84
#
#         installment
# 427211       762.08
# 206088       343.39
# 136020       648.56
# 412305       609.73
# 36159        282.40
#
# [5 rows x 152 columns]

# %%
ref_categories=['grade:G',
               'home_ownership:RENT_OTHER_NONE_ANY',
               'addr_state:ND_NE_IA_NC_FL_HI_AL',
               'verification_status:Verified',
                'purpose:educ_sm_b_wedd_ren_en_mov_house',
                'initial_list_status:f',
                'term:60',
                'emp_length:0',
                'mths_since_issued_date:>84',
                'int_rate:20.281',
                'mths_since_earliest_cr_line:<140',
                'delinq_2yrs:>18',
                'inq_last_6mths:7-9',
                'open_acc:=0',
                'pub_rec:0-3',
                'total_acc:>85',
                'acc_now_delinq:<0',
                'total_rev_hi_lim:<=5k',
                'annual_inc:<20k',
                'dti:>40',
                'mths_since_last_delinq:0-3',
                'mths_since_last_record:Missing'
               ]

# %%
inputs_train=inputs_train_with_ref_category.drop(ref_categories,axis=1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:OK_TN_MO_LA_MD_NC  ...  mths_since_last_delinq:31-56  \
# 427211                             0  ...                             0
# 206088                             0  ...                             0
# 136020                             0  ...                             1
# 412305                             0  ...                             0
# 36159                              0  ...                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:0-90  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#         mths_since_last_record:90-120  mths_since_last_record:120-127  \
# 427211                              0                               0
# 206088                              0                               0
# 136020                              0                               0
# 412305                              0                               0
# 36159                               0                               0
#
#         mths_since_last_record:>=127  loan_amnt  funded_amnt  int_rate  \
# 427211                             0      24000        24000      8.90
# 206088                             0      10000        10000     14.33
# 136020                             0      20425        20425      8.90
# 412305                             0      17200        17200     16.59
# 36159                              0       8400         8400     12.84
#
#         installment
# 427211       762.08
# 206088       343.39
# 136020       648.56
# 412305       609.73
# 36159        282.40
#
# [5 rows x 130 columns]

# %% [markdown]
# PD MODLE ESTIMATION

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression(max_iter=200)

# %%
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:OK_TN_MO_LA_MD_NC  ...  mths_since_last_delinq:31-56  \
# 427211                             0  ...                             0
# 206088                             0  ...                             0
# 136020                             0  ...                             1
# 412305                             0  ...                             0
# 36159                              0  ...                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:0-90  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#         mths_since_last_record:90-120  mths_since_last_record:120-127  \
# 427211                              0                               0
# 206088                              0                               0
# 136020                              0                               0
# 412305                              0                               0
# 36159                               0                               0
#
#         mths_since_last_record:>=127  loan_amnt  funded_amnt  int_rate  \
# 427211                             0      24000        24000      8.90
# 206088                             0      10000        10000     14.33
# 136020                             0      20425        20425      8.90
# 412305                             0      17200        17200     16.59
# 36159                              0       8400         8400     12.84
#
#         installment
# 427211       762.08
# 206088       343.39
# 136020       648.56
# 412305       609.73
# 36159        282.40
#
# [5 rows x 130 columns]

# %%
pd.options.display.max_rows = None

# %%
inputs_train.isnull().sum()
# Out:
# grade:A                                0
# grade:B                                0
# grade:C                                0
# grade:D                                0
# grade:E                                0
# grade:F                                0
# home_ownership:OWN                     0
# home_ownership:MORTGAGE                0
# addr_state:NM_VA                       0
# addr_state:OK_TN_MO_LA_MD_NC           0
# addr_state:UT_KY_AZ_NJ                 0
# addr_state:AR_MI_PA_OH_MN              0
# addr_state:RI_MA_DE_SD_IN              0
# addr_state:GA_WA_OR                    0
# addr_state:WI_MT                       0
# addr_state:IL_CT                       0
# addr_state:KS_SC_CO_VT_AK_MS           0
# addr_state:WV_NH_WY_DC_ME_ID           0
# verification_status:Source Verified    0
# verification_status:Not Verified       0
# purpose:small_business                 0
# purpose:educational                    0
# purpose:renewable_energy               0
# purpose:moving                         0
# purpose:house                          0
# purpose:other                          0
# purpose:medical                        0
# purpose:wedding                        0
# purpose:vacation                       0
# purpose:debt_consolidation             0
# purpose:home_improvement               0
# purpose:major_purchase                 0
# purpose:car                            0
# purpose:credit_card                    0
# initial_list_status:w                  0
# term:36                                0
# emp_length:1                           0
# emp_length:2-4                         0
# emp_length:5-6                         0
# emp_length:7-9                         0
# emp_length:10                          0
# mths_since_issued_date:<38             0
# mths_since_issued_date:38-39           0
# mths_since_issued_date:40-41           0
# mths_since_issued_date:42-48           0
# mths_since_issued_date:49-52           0
# mths_since_issued_date:53-64           0
# mths_since_issued_date:65-84           0
# int_rate:<9.548                        0
# int_rate:9.548-12.025                  0
# int_rate:12.025-15.74                  0
# int_rate:15.74-20.281                  0
# mths_since_earliest_cr_line:140-239    0
# mths_since_earliest_cr_line:240-339    0
# mths_since_earliest_cr_line:340-439    0
# mths_since_earliest_cr_line:440-539    0
# mths_since_earliest_cr_line:540-600    0
# mths_since_earliest_cr_line:>600       0
# delinq_2yrs:0                          0
# delinq_2yrs:0-3                        0
# delinq_2yrs:3-7                        0
# delinq_2yrs:7-9                        0
# delinq_2yrs:9-11                       0
# delinq_2yrs:11-12                      0
# delinq_2yrs:12-18                      0
# inq_last_6mths:0                       0
# inq_last_6mths:0-3                     0
# inq_last_6mths:3-7                     0
# inq_last_6mths:9-11                    0
# inq_last_6mths:11-12                   0
# inq_last_6mths:12-18                   0
# inq_last_6mths:18                      0
# open_acc:0-1                           0
# open_acc:1-4                           0
# open_acc:4-28                          0
# open_acc:28-35                         0
# open_acc:35-45                         0
# open_acc:>45                           0
# pub_rec:3-6                            0
# pub_rec:6-8                            0
# pub_rec:8                              0
# total_acc:<0                           0
# total_acc:0-4                          0
# total_acc:4-62                         0
# total_acc:62-72                        0
# total_acc:72-85                        0
# acc_now_delinq:0-1                     0
# acc_now_delinq:1-2                     0
# acc_now_delinq:2-3                     0
# acc_now_delinq:3-5                     0
# acc_now_delinq:>5                      0
# annual_inc:20k-30k                     0
# annual_inc:30k-40k                     0
# annual_inc:40k-50k                     0
# annual_inc:50k-60k                     0
# annual_inc:60k-70k                     0
# annual_inc:70k-80k                     0
# annual_inc:80k-90k                     0
# annual_inc:90k-100k                    0
# annual_inc:100k-120k                   0
# annual_inc:120k-140k                   0
# annual_inc:>140k                       0
# total_rev_hi_lim:5k_10k                0
# total_rev_hi_lim:10k_20k               0
# total_rev_hi_lim:20k_30k               0
# total_rev_hi_lim:30k_40k               0
# total_rev_hi_lim:40k_50k               0
# total_rev_hi_lim:50k_65k               0
# total_rev_hi_lim:65k_80k               0
# total_rev_hi_lim:>80k                  0
# dti:<5                                 0
# dti:5-10                               0
# dti:10-15                              0
# dti:15-20                              0
# dti:20-25                              0
# dti:25-30                              0
# dti:30-35                              0
# dti:35-40                              0
# mths_since_last_delinq:Missing         0
# mths_since_last_delinq:4-30            0
# mths_since_last_delinq:31-56           0
# mths_since_last_delinq:>=57            0
# mths_since_last_record:0-90            0
# mths_since_last_record:90-120          0
# mths_since_last_record:120-127         0
# mths_since_last_record:>=127           0
# loan_amnt                              0
# funded_amnt                            0
# int_rate                               0
# installment                            0
# dtype: int64

# %%
inputs_train=inputs_train.astype(float)

# %%
load_data_targets_train=load_data_targets_train.astype(float)

# %%
reg.fit(inputs_train,load_data_targets_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
inputs_test_with_ref_category= load_data_inputs_test.reindex(feature_selection, axis='columns')

# %%
inputs_test= inputs_test_with_ref_category.drop(ref_categories,axis=1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:OK_TN_MO_LA_MD_NC  ...  mths_since_last_delinq:31-56  \
# 427211                             0  ...                             0
# 206088                             0  ...                             0
# 136020                             0  ...                             1
# 412305                             0  ...                             0
# 36159                              0  ...                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:0-90  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#         mths_since_last_record:90-120  mths_since_last_record:120-127  \
# 427211                              0                               0
# 206088                              0                               0
# 136020                              0                               0
# 412305                              0                               0
# 36159                               0                               0
#
#         mths_since_last_record:>=127  loan_amnt  funded_amnt  int_rate  \
# 427211                             0      24000        24000      8.90
# 206088                             0      10000        10000     14.33
# 136020                             0      20425        20425      8.90
# 412305                             0      17200        17200     16.59
# 36159                              0       8400         8400     12.84
#
#         installment
# 427211       762.08
# 206088       343.39
# 136020       648.56
# 412305       609.73
# 36159        282.40
#
# [5 rows x 130 columns]

# %%
inputs_test.isna().sum()
# Out:
# grade:A                                0
# grade:B                                0
# grade:C                                0
# grade:D                                0
# grade:E                                0
# grade:F                                0
# home_ownership:OWN                     0
# home_ownership:MORTGAGE                0
# addr_state:NM_VA                       0
# addr_state:OK_TN_MO_LA_MD_NC           0
# addr_state:UT_KY_AZ_NJ                 0
# addr_state:AR_MI_PA_OH_MN              0
# addr_state:RI_MA_DE_SD_IN              0
# addr_state:GA_WA_OR                    0
# addr_state:WI_MT                       0
# addr_state:IL_CT                       0
# addr_state:KS_SC_CO_VT_AK_MS           0
# addr_state:WV_NH_WY_DC_ME_ID           0
# verification_status:Source Verified    0
# verification_status:Not Verified       0
# purpose:small_business                 0
# purpose:educational                    0
# purpose:renewable_energy               0
# purpose:moving                         0
# purpose:house                          0
# purpose:other                          0
# purpose:medical                        0
# purpose:wedding                        0
# purpose:vacation                       0
# purpose:debt_consolidation             0
# purpose:home_improvement               0
# purpose:major_purchase                 0
# purpose:car                            0
# purpose:credit_card                    0
# initial_list_status:w                  0
# term:36                                0
# emp_length:1                           0
# emp_length:2-4                         0
# emp_length:5-6                         0
# emp_length:7-9                         0
# emp_length:10                          0
# mths_since_issued_date:<38             0
# mths_since_issued_date:38-39           0
# mths_since_issued_date:40-41           0
# mths_since_issued_date:42-48           0
# mths_since_issued_date:49-52           0
# mths_since_issued_date:53-64           0
# mths_since_issued_date:65-84           0
# int_rate:<9.548                        0
# int_rate:9.548-12.025                  0
# int_rate:12.025-15.74                  0
# int_rate:15.74-20.281                  0
# mths_since_earliest_cr_line:140-239    0
# mths_since_earliest_cr_line:240-339    0
# mths_since_earliest_cr_line:340-439    0
# mths_since_earliest_cr_line:440-539    0
# mths_since_earliest_cr_line:540-600    0
# mths_since_earliest_cr_line:>600       0
# delinq_2yrs:0                          0
# delinq_2yrs:0-3                        0
# delinq_2yrs:3-7                        0
# delinq_2yrs:7-9                        0
# delinq_2yrs:9-11                       0
# delinq_2yrs:11-12                      0
# delinq_2yrs:12-18                      0
# inq_last_6mths:0                       0
# inq_last_6mths:0-3                     0
# inq_last_6mths:3-7                     0
# inq_last_6mths:9-11                    0
# inq_last_6mths:11-12                   0
# inq_last_6mths:12-18                   0
# inq_last_6mths:18                      0
# open_acc:0-1                           0
# open_acc:1-4                           0
# open_acc:4-28                          0
# open_acc:28-35                         0
# open_acc:35-45                         0
# open_acc:>45                           0
# pub_rec:3-6                            0
# pub_rec:6-8                            0
# pub_rec:8                              0
# total_acc:<0                           0
# total_acc:0-4                          0
# total_acc:4-62                         0
# total_acc:62-72                        0
# total_acc:72-85                        0
# acc_now_delinq:0-1                     0
# acc_now_delinq:1-2                     0
# acc_now_delinq:2-3                     0
# acc_now_delinq:3-5                     0
# acc_now_delinq:>5                      0
# annual_inc:20k-30k                     0
# annual_inc:30k-40k                     0
# annual_inc:40k-50k                     0
# annual_inc:50k-60k                     0
# annual_inc:60k-70k                     0
# annual_inc:70k-80k                     0
# annual_inc:80k-90k                     0
# annual_inc:90k-100k                    0
# annual_inc:100k-120k                   0
# annual_inc:120k-140k                   0
# annual_inc:>140k                       0
# total_rev_hi_lim:5k_10k                0
# total_rev_hi_lim:10k_20k               0
# total_rev_hi_lim:20k_30k               0
# total_rev_hi_lim:30k_40k               0
# total_rev_hi_lim:40k_50k               0
# total_rev_hi_lim:50k_65k               0
# total_rev_hi_lim:65k_80k               0
# total_rev_hi_lim:>80k                  0
# dti:<5                                 0
# dti:5-10                               0
# dti:10-15                              0
# dti:15-20                              0
# dti:20-25                              0
# dti:25-30                              0
# dti:30-35                              0
# dti:35-40                              0
# mths_since_last_delinq:Missing         0
# mths_since_last_delinq:4-30            0
# mths_since_last_delinq:31-56           0
# mths_since_last_delinq:>=57            0
# mths_since_last_record:0-90            0
# mths_since_last_record:90-120          0
# mths_since_last_record:120-127         0
# mths_since_last_record:>=127           0
# loan_amnt                              0
# funded_amnt                            0
# int_rate                               0
# installment                            0
# dtype: int64

# %%
y_hat_test= reg.predict(inputs_test)

# %%
a=y_hat_test.astype(int)

# %%
y_hat_test_proba = reg.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.04207975, 0.95792025],
#        [0.113094  , 0.886906  ],
#        [0.03585108, 0.96414892],
#        ...,
#        [0.09227426, 0.90772574],
#        [0.07317826, 0.92682174],
#        [0.05673394, 0.94326606]])

# %%
y_hat_test_proba[: ][: ,1]
# Out:
# array([0.95792025, 0.886906  , 0.96414892, ..., 0.90772574, 0.92682174,
#        0.94326606])

# %%
y_hat_test_proba=y_hat_test_proba[: ][: ,1]

# %%
loan_data_targets_test_temp = load_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop= True, inplace= True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp,pd.DataFrame(y_hat_test_proba)], axis=1)

# %%
df_actual_predicted_probs.shape
# Out:
# (373028, 2)

# %%
df_actual_predicted_probs.columns = ['load_data_targets_test','y_hat_test_proba']

# %%
df_actual_predicted_probs.index=load_data_inputs_test.index

# %%
df_actual_predicted_probs.head()
# Out:
#         load_data_targets_test  y_hat_test_proba
# 427211                     1.0          0.957920
# 206088                     1.0          0.886906
# 136020                     1.0          0.964149
# 412305                     1.0          0.835723
# 36159                      1.0          0.825855

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test']=np.where(df_actual_predicted_probs['y_hat_test_proba']>tr,1,0)

# %%
pd.crosstab(df_actual_predicted_probs['load_data_targets_test'],df_actual_predicted_probs['y_hat_test'],
    rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0.0         4881   5309
# 1.0        39614  43453

# %% [markdown]
# # Generalized function for model building

# %%
def x_tr_model(model,x_train,y_train,x_test,y_test,tr):
    model.fit(x_train,y_train)
    pred_y = model.predict(x_test)
    y_hat_test_proba = reg.predict_proba(inputs_test)
    y_hat_test_proba=y_hat_test_proba[: ][: ,1]
    loan_data_targets_test_temp = y_test
    loan_data_targets_test_temp.reset_index(drop= True, inplace= True)
    df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp,pd.DataFrame(y_hat_test_proba)], axis=1)
    df_actual_predicted_probs.columns =  ['load_data_targets_test','y_hat_test_proba']
    df_actual_predicted_probs.index=load_data_inputs_test.index
    df_actual_predicted_probs['y_hat_test']= np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1,0)
   
    return pd.crosstab(df_actual_predicted_probs['load_data_targets_test'],df_actual_predicted_probs['y_hat_test'],rownames = ['Actual'], colnames = ['Predicted'])

# %%
x_tr_model(LogisticRegression(max_iter=150),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.9)
# Out:
# Predicted      0      1
# Actual
# 0.0         4881   5309
# 1.0        39614  43453

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
x_tr_model(RandomForestClassifier(),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.85)
# Out:
# Predicted      0      1
# Actual
# 0.0         2241   7949
# 1.0        18653  64414

# %%
x_tr_model(DecisionTreeClassifier(),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.8)
# Out:
# Predicted     0      1
# Actual
# 0.0         943   9247
# 1.0        7782  75285

# %%
x_tr_model(GradientBoostingClassifier(),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.8)
# Out:
# Predicted     0      1
# Actual
# 0.0         943   9247
# 1.0        7782  75285

# %% [markdown]
# ### **Hyper-Parameter Tuning**

# %%
def random_Search(model,X_train, Y_train,param_grid):

    from sklearn.model_selection import RandomizedSearchCV    
    random = RandomizedSearchCV(estimator = model, param_distributions = param_grid, n_iter = 10, cv = 2, verbose=2, random_state=42, n_jobs = -1)# Fit the random search model
    random.fit(X_train, Y_train)
    print(random.best_params_)

# %%
DTR_para_grid = {
                  "splitter":["best","random"],
            "max_depth" : [1,3,12],
           "min_samples_leaf":[1,4,5,9],
           "min_weight_fraction_leaf":[0.1,0.3,0,0.7,0.9],
           "max_features":["auto","log2"],
           "max_leaf_nodes":[10,40,60,80]
              }

random_Search(DecisionTreeClassifier(),inputs_train,load_data_targets_train, DTR_para_grid)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# {'splitter': 'random', 'min_weight_fraction_leaf': 0.3, 'min_samples_leaf': 4, 'max_leaf_nodes': 60, 'max_features': 'log2', 'max_depth': 12}

# %%
rf_para_grid = {'n_estimators': [int(x) for x in np.arange(200,500,100)],
               'max_features': ['auto', 'sqrt'],
               'max_depth': [int(x) for x in np.linspace(10, 80, num = 11)],
               'min_samples_leaf': [1, 2, 4]
               
               }
random_Search(RandomForestClassifier(),inputs_train,load_data_targets_train, rf_para_grid)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.3, splitter=random; total time=   2.8s
# [CV] END max_depth=3, max_features=auto, max_leaf_nodes=10, min_samples_leaf=4, min_weight_fraction_leaf=0, splitter=best; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time= 1.4min
# [CV] END max_depth=59, max_features=auto, min_samples_leaf=1, n_estimators=200; total time=   0.8s
# [CV] END max_depth=59, max_features=sqrt, min_samples_leaf=2, n_estimators=400; total time= 2.7min
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.3, splitter=random; total time=   2.7s
# [CV] END max_depth=3, max_features=auto, max_leaf_nodes=10, min_samples_leaf=4, min_weight_fraction_leaf=0, splitter=best; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time= 1.4min
# [CV] END max_depth=59, max_features=auto, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=59, max_features=sqrt, min_samples_leaf=2, n_estimators=400; total time= 2.8min
# {'n_estimators': 200, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 66}

# %%
x_tr_model(DecisionTreeClassifier(splitter= 'random', min_weight_fraction_leaf= 0.3, min_samples_leaf= 4, max_leaf_nodes= 60, max_features='log2', max_depth=12),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.8)
# Out:
# Predicted     0      1
# Actual
# 0.0         943   9247
# 1.0        7782  75285

# %%
x_tr_model(RandomForestClassifier(n_estimators=200,min_samples_leaf=2,max_features='sqrt',max_depth=66),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.85)
# Out:
# [CV] END max_depth=3, max_features=auto, max_leaf_nodes=10, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.9s
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=80, min_samples_leaf=1, min_weight_fraction_leaf=0.3, splitter=random; total time=   2.0s
# [CV] END max_depth=1, max_features=auto, max_leaf_nodes=60, min_samples_leaf=1, min_weight_fraction_leaf=0.7, splitter=best; total time=   0.2s
# [CV] END max_depth=52, max_features=auto, min_samples_leaf=4, n_estimators=200; total time=   1.1s
# [CV] END max_depth=66, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time= 2.1min
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=1, n_estimators=200; total time=   0.2s
# [CV] END max_depth=73, max_features=auto, min_samples_leaf=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=3, max_features=auto, max_leaf_nodes=10, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.9s
# [CV] END max_depth=1, max_features=log2, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   2.0s
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=40, min_samples_leaf=9, min_weight_fraction_leaf=0.9, splitter=best; total time=   0.2s
# [CV] END max_depth=52, max_features=auto, min_samples_leaf=4, n_estimators=200; total time=   1.1s
# [CV] END max_depth=66, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time= 2.1min
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=1, n_estimators=200; total time=   0.2s
# [CV] END max_depth=73, max_features=auto, min_samples_leaf=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=10, min_samples_leaf=9, min_weight_fraction_leaf=0.7, splitter=best; total time=   0.9s
# [CV] END max_depth=1, max_features=log2, max_leaf_nodes=40, min_samples_leaf=4, min_weight_fraction_leaf=0, splitter=random; total time=   2.0s
# [CV] END max_depth=59, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time= 2.0min
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time= 1.2min
# [CV] END max_depth=3, max_features=auto, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.7, splitter=random; total time=   0.9s
# [CV] END max_depth=1, max_features=log2, max_leaf_nodes=40, min_samples_leaf=4, min_weight_fraction_leaf=0, splitter=random; total time=   2.0s
# [CV] END max_depth=12, max_features=log2, max_leaf_nodes=40, min_samples_leaf=9, min_weight_fraction_leaf=0.9, splitter=best; total time=   0.2s
# [CV] END max_depth=59, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time= 2.0min
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time= 1.2min
# Predicted      0      1
# Actual
# 0.0         2241   7949
# 1.0        18653  64414

# %%
gb_parameters = {
    "n_estimators":[50,250,500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,10]
}
random_Search(GradientBoostingClassifier(),inputs_train,load_data_targets_train,gb_parameters )
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'n_estimators': 50, 'max_depth': 1, 'learning_rate': 0.01}

# %%
x_tr_model(GradientBoostingClassifier(n_estimators=50,max_depth=1,learning_rate=0.01),inputs_train,load_data_targets_train,inputs_test,load_data_targets_test,0.8)
# Out:
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=  14.2s
# [CV] END .....learning_rate=10, max_depth=7, n_estimators=50; total time= 1.8min
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time= 2.7min
# Predicted     0      1
# Actual
# 0.0         943   9247
# 1.0        7782  75285

# %%
grad_boss = GradientBoostingClassifier(n_estimators= 50, max_depth= 1, learning_rate= 0.01)
grad_boss.fit(inputs_train,load_data_targets_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=1, n_estimators=50)

# %%
import pickle
pickle.dump(grad_boss,open('pd_model_gradient.sav','wb'))
